# %%
1+1
# Out:
# 2

# %%
import numpy as np

# %%
x=np.array([1,2,3,4,5])

# %%
y=x*2

# %%
x
# Out:
# array([ 2,  4,  6,  8, 10])

# %%
y
# Out:
# array([ 2,  4,  6,  8, 10])

# %%
x
# Out:
# array([1, 2, 3, 4, 5])

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y)
plt.title('shuvo')
plt.xlabel("x")
plt.show()

# %%
plt.plot(x,y,color='b',linewidth=2,linestyle=':')
plt.title('shuvo')
plt.xlabel("x")
plt.show()

# %%
s={'s':156,'h':56,'l':78}

# %%
n=list(s.keys())

# %%
v=list(s.values())

# %%
plt.bar(n,v)
plt.show()
